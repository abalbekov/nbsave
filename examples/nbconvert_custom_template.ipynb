# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#two-hash-header" data-toc-modified-id="two-hash-header-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>two-hash header</a></span><ul class="toc-item"><li><span><a href="#three-hash-header" data-toc-modified-id="three-hash-header-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>three-hash header</a></span></li><li><span><a href="#three-hash-header" data-toc-modified-id="three-hash-header-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>three-hash header</a></span></li></ul></li><li><span><a href="#another-two-hash-header" data-toc-modified-id="another-two-hash-header-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>another two-hash header</a></span><ul class="toc-item"><li><span><a href="#three-hash-header" data-toc-modified-id="three-hash-header-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>three-hash header</a></span></li><li><span><a href="#three-hash-header" data-toc-modified-id="three-hash-header-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>three-hash header</a></span></li></ul></li><li><span><a href="#another-two-hash-header" data-toc-modified-id="another-two-hash-header-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>another two-hash header</a></span><ul class="toc-item"><li><span><a href="#three-hash-header" data-toc-modified-id="three-hash-header-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>three-hash header</a></span></li><li><span><a href="#three-hash-header" data-toc-modified-id="three-hash-header-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>three-hash header</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Example of using nbconvert custom template with custom exporter.
#
# This is nbcovert custom template for saving a Jupyter notebook as html file.
# The template will:
#     - add hide/show buttons for code and output cells
#     - add cell execution time taken from cell metadata stored by "executetime" Jupyter extension
#     - enumerate markdown headings
#     - adjust REF anchors in Table of Content generated by "toc2" Jupyter extension to match enumerated headings
#
# The custom Jinja2 template name is "custom_template".
# The template extends "classic" html template.
# The template relies on several jinja2 filters implemented as functions in a custom exporter.
# The exporter name is "custom_exporter.AddFilters", implemented in Python package custom_exporter.
# Therefore nbconvert needs to be called with both "--to" and "--template" parameters as below.

# %% [markdown]
# # Testing headers
# ## two-hash header
# ### three-hash header
# ### three-hash header
# ## another two-hash header
# ### three-hash header
# ### three-hash header
# ## another two-hash header
# ### three-hash header
# ### three-hash header

# %%
# %load_ext sql
# %config SqlMagic.feedback=False
# %config SqlMagic.feedback=False
# %config SqlMagic.displaylimit=10

# %%
# %%sql oracle://@mdm11d_12 res <<
# SELECT LEVEL/10 as x, sin(LEVEL/10) as y
# FROM dual
# CONNECT BY LEVEL <= 300
# Out:
# Returning data to local variable res

# %%
df=res.DataFrame().astype(float)

# %%
_=df.plot(x='x')

# %%
! jupyter nbconvert nbconvert_custom_template.ipynb --to=custom_exporter.AddFilters --template custom_template
# Out:
# [NbConvertApp] Converting notebook nbconvert_custom_template.ipynb to custom_exporter.AddFilters
